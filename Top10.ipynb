# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("311_Service_Requests_2020.csv") #read dataset
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (20,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45285347  01/01/2020 12:00:00 AM  01/10/2020 12:00:01 AM  DOHMH
# 1    45285651  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 2    45285821  01/01/2020 12:00:00 AM  01/02/2020 09:50:09 AM  DOHMH
# 3    45287907  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 4    45288240  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
#
#                                Agency Name  Complaint Type Descriptor  \
# 0  Department of Health and Mental Hygiene  Food Poisoning  3 or More
# 1  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 2  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# ...

# %%
df_10027 = df[df['Incident Zip']==10027] #get info for 10027 zip code
df_10027.head()
# Out:
#      Unique Key            Created Date             Closed Date Agency  \
# 305    45278190  01/01/2020 01:10:07 AM  01/01/2020 09:00:02 AM   NYPD
# 542    45281550  01/01/2020 01:52:36 AM  01/01/2020 02:58:35 AM   NYPD
# 553    45281044  01/01/2020 01:54:22 AM  01/01/2020 11:12:27 AM   NYPD
# 614    45289780  01/01/2020 02:04:07 AM  01/01/2020 05:06:45 AM   NYPD
# 693    45287804  01/01/2020 02:18:51 AM  01/01/2020 05:07:33 AM   NYPD
#
#                          Agency Name           Complaint Type  \
# 305  New York City Police Department       Noise - Commercial
# 542  New York City Police Department      Noise - Residential
# 553  New York City Police Department  Noise - Street/Sidewalk
# 614  New York City Police Department      Noise - Residential
# 693  New York City Police Department       Noise - Commercial
#
#            Descriptor               Location Type  Incident Zip  \
# 305  Loud Music/Party         Club/Bar/Restaurant       10027.0
# ...

# %%
top10 = df_10027.groupby('Complaint Type').size().sort_values(ascending=False).head(10)
#calculate incidents number in each complaint type, sort it descendingly and display top 10

# %%
top10
# Out:
# Complaint Type
# Noise - Residential            3610
# Noise - Street/Sidewalk        3087
# HEAT/HOT WATER                 2138
# Illegal Parking                1118
# Non-Emergency Police Matter     862
# Illegal Fireworks               779
# Noise - Vehicle                 647
# UNSANITARY CONDITION            628
# PLUMBING                        465
# Noise                           443
# dtype: int64
